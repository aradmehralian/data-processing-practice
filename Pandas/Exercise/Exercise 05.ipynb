# %% [markdown]
# # Pandas Exercise Session 05

# %%
import pandas as pd

# %%
df = pd.read_csv("data/winequality-red.csv", sep=";")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df["free sulfur dioxide"].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df["quality"].astype("float32")
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       6.0
# 4       5.0
#        ...
# 1594    5.0
# 1595    6.0
# 1596    6.0
# 1597    5.0
# 1598    6.0
# Name: quality, Length: 1599, dtype: float32

# %%
df.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
pd.set_option("display.max_rows", 8)

# %%
reviews = pd.read_csv("data/winemag-data-130k-v2.csv", index_col=0)

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# ...          ...                                                ...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...

# %%
reviews["price"].dtype
# Out:
# dtype('float64')

# %%
reviews.dtypes.value_counts()
# Out:
# object     11
# int64       1
# float64     1
# Name: count, dtype: int64

# %%
reviews["points"].astype("float32")
# Out:
# 0         87.0
# 1         87.0
# 2         87.0
# 3         87.0
#           ...
# 129967    90.0
# 129968    90.0
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float32

# %%
pd.isnull(reviews["country"])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
#           ...
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
reviews[pd.isnull(reviews["country"])]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# ...        ...                                                ...
# 129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# 3131                          Partager      83    NaN      NaN      NaN
# 4243          Red Naturally Semi-Sweet      88   18.0      NaN      NaN
# ...

# %%
reviews["region_1"].fillna("Unknown")
# Out:
# 0                        Etna
# 1                     Unknown
# 2           Willamette Valley
# 3         Lake Michigan Shore
#                  ...
# 129967                 Oregon
# 129968                 Alsace
# 129969                 Alsace
# 129970                 Alsace
# Name: region_1, Length: 129971, dtype: object

# %%
reviews["region_1"].fillna("Unknown").value_counts()
# Out:
# region_1
# Unknown                               21247
# Napa Valley                            4480
# Columbia Valley (WA)                   4124
# Russian River Valley                   3091
#                                       ...
# Sonoma County-Santa Barbara County        1
# Del Veneto                                1
# Bardolino Superiore                       1
# Paestum                                   1
# Name: count, Length: 1230, dtype: int64

# %%
reviews["region_1"].dropna().value_counts()
# Out:
# region_1
# Napa Valley                  4480
# Columbia Valley (WA)         4124
# Russian River Valley         3091
# California                   2629
#                              ...
# Nasco di Cagliari               1
# Dolcetto d'Alba Superiore       1
# Medrano                         1
# Collioure                       1
# Name: count, Length: 1229, dtype: int64

# %%
reviews.shape
# Out:
# (129971, 13)

# %%
reviews["taster_twitter_handle"].replace("@vossroger", "@m$Mroger")
# Out:
# 0         @kerinokeefe
# 1            @m$Mroger
# 2          @paulgwine
# 3                  NaN
#               ...
# 129967     @paulgwine
# 129968       @m$Mroger
# 129969       @m$Mroger
# 129970       @m$Mroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
print("Columns:\n")
for indx, column in enumerate(reviews.columns):
    print(column)
    if indx == len(reviews.columns) - 1:
        continue
    print("-" * 10)
# Out:
# Columns:
#
# country
# ----------
# description
# ----------
# designation
# ----------
# points
# ----------
# price
# ----------
# province
# ----------
# region_1
# ----------
# region_2
# ----------
# taster_name
# ----------
# taster_twitter_handle
# ----------
# title
# ----------
# variety
# ----------
# winery

# %%
reviews["points"].dtype
# Out:
# dtype('int64')

# %%
point_strings = reviews["points"].astype("str")

# %%
point_strings
# Out:
# 0         87
# 1         87
# 2         87
# 3         87
#           ..
# 129967    90
# 129968    90
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: object

# %%
reviews.points.memory_usage(deep=True, index=False) / 1e6
# Out:
# 1.039768

# %%
point_strings.memory_usage(deep=True, index=False) / 1e6
# Out:
# 7.668308

# %%
reviews.price.isnull().sum()
# Out:
# np.int64(8996)

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews["region_1"].fillna("Unknown").value_counts()
# Out:
# region_1
# Unknown                               21247
# Napa Valley                            4480
# Columbia Valley (WA)                   4124
# Russian River Valley                   3091
#                                       ...
# Sonoma County-Santa Barbara County        1
# Del Veneto                                1
# Bardolino Superiore                       1
# Paestum                                   1
# Name: count, Length: 1230, dtype: int64
